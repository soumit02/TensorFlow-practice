# %%
import tensorflow as tf

# %%
# Load model
model = tf.keras.models.load_model("mnist_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Create converter
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# %%
# Quantization
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# %%
# Convert
tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: C:\Users\LENOVO\AppData\Local\Temp\tmp3pdj4kq3\assets
# INFO:tensorflow:Assets written to: C:\Users\LENOVO\AppData\Local\Temp\tmp3pdj4kq3\assets
# Saved artifact at 'C:\Users\LENOVO\AppData\Local\Temp\tmp3pdj4kq3'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28, 28), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   3097722055056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3097722055632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3097722054864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3097722054096: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# Save
with open("mnist_quantized.tflite", "wb") as file:
    file.write(tflite_model)

# %%
print("Quantized model saved!")
# Out:
# Quantized model saved!
